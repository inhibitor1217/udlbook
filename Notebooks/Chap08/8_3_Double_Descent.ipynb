# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/_1/lv4x6t2d7mx3wxjgz2q9kmp40000gn/T/pip-req-build-7f48cw3m
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/_1/lv4x6t2d7mx3wxjgz2q9kmp40000gn/T/pip-req-build-7f48cw3m
#   Resolved https://github.com/greydanus/mnist1d to commit 68cb6b2d1d3a956cc2e9035e5a9860b66e33d642
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from mnist1d==0.0.2.post15) (2.31.0)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from mnist1d==0.0.2.post15) (1.24.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (from mnist1d==0.0.2.post15) (3.8.1)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from mnist1d==0.0.2.post15) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post15) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post15) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post15) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post15) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post15) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post15) (1.13.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('mps' if torch.backends.mps.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: mps

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302167, train error 89.55,  test loss 2.302024, test error 90.07
# Epoch   100, train loss 1.922397, train error 71.68,  test loss 1.773369, test error 70.68
# Epoch   200, train loss 1.910935, train error 72.55,  test loss 1.758252, test error 70.32
# Epoch   300, train loss 1.910626, train error 72.05,  test loss 1.739256, test error 70.22
# Epoch   400, train loss 1.905694, train error 71.95,  test loss 1.737069, test error 70.40
# Epoch   500, train loss 1.905013, train error 71.82,  test loss 1.737677, test error 70.35
# Epoch   600, train loss 1.902908, train error 71.70,  test loss 1.735872, test error 69.05
# Epoch   700, train loss 1.902169, train error 70.75,  test loss 1.740644, test error 68.78
# Epoch   800, train loss 1.901142, train error 70.47,  test loss 1.744750, test error 69.50
# Epoch   900, train loss 1.906959, train error 71.90,  test loss 1.724502, test error 70.68
# Training model with   4 hidden variables
# Epoch     0, train loss 2.285748, train error 86.12,  test loss 2.285007, test error 84.97
# Epoch   100, train loss 1.819495, train error 67.32,  test loss 1.711265, test error 67.62
# Epoch   200, train loss 1.797781, train error 65.53,  test loss 1.696622, test error 66.53
# Epoch   300, train loss 1.787980, train error 65.50,  test loss 1.700786, test error 66.10
# Epoch   400, train loss 1.782560, train error 65.03,  test loss 1.697029, test error 65.25
# Epoch   500, train loss 1.780713, train error 64.80,  test loss 1.710617, test error 65.62
# Epoch   600, train loss 1.784145, train error 65.07,  test loss 1.701972, test error 65.88
# Epoch   700, train loss 1.774798, train error 64.53,  test loss 1.710283, test error 65.18
# Epoch   800, train loss 1.774661, train error 64.70,  test loss 1.712282, test error 65.75
# Epoch   900, train loss 1.772605, train error 64.47,  test loss 1.729319, test error 65.75
# Training model with   6 hidden variables
# Epoch     0, train loss 2.300324, train error 88.38,  test loss 2.304127, test error 89.10
# Epoch   100, train loss 1.649382, train error 57.38,  test loss 1.458997, test error 55.85
# Epoch   200, train loss 1.638183, train error 57.22,  test loss 1.451580, test error 55.12
# Epoch   300, train loss 1.636062, train error 57.65,  test loss 1.459906, test error 56.75
# Epoch   400, train loss 1.628239, train error 57.35,  test loss 1.444950, test error 56.08
# Epoch   500, train loss 1.627521, train error 57.38,  test loss 1.452670, test error 55.95
# Epoch   600, train loss 1.627356, train error 57.00,  test loss 1.454423, test error 56.08
# Epoch   700, train loss 1.628460, train error 56.80,  test loss 1.466666, test error 56.70
# Epoch   800, train loss 1.626724, train error 57.58,  test loss 1.459015, test error 56.45
# Epoch   900, train loss 1.622713, train error 56.90,  test loss 1.460907, test error 56.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.283405, train error 86.45,  test loss 2.280376, test error 86.00
# Epoch   100, train loss 1.642229, train error 59.17,  test loss 1.470096, test error 57.50
# Epoch   200, train loss 1.588491, train error 55.50,  test loss 1.430002, test error 54.60
# Epoch   300, train loss 1.569828, train error 55.22,  test loss 1.435243, test error 55.00
# Epoch   400, train loss 1.560929, train error 55.00,  test loss 1.444567, test error 54.97
# Epoch   500, train loss 1.556686, train error 55.30,  test loss 1.465548, test error 54.88
# Epoch   600, train loss 1.550839, train error 55.25,  test loss 1.474390, test error 54.80
# Epoch   700, train loss 1.545627, train error 54.65,  test loss 1.480454, test error 55.35
# Epoch   800, train loss 1.540314, train error 54.72,  test loss 1.475231, test error 55.30
# Epoch   900, train loss 1.537998, train error 55.05,  test loss 1.496508, test error 55.83
# Training model with  10 hidden variables
# Epoch     0, train loss 2.290721, train error 87.68,  test loss 2.296414, test error 88.70
# Epoch   100, train loss 1.536889, train error 53.22,  test loss 1.410918, test error 52.15
# Epoch   200, train loss 1.436715, train error 48.25,  test loss 1.322156, test error 48.83
# Epoch   300, train loss 1.411644, train error 47.58,  test loss 1.314858, test error 48.12
# Epoch   400, train loss 1.393329, train error 47.20,  test loss 1.332257, test error 48.97
# Epoch   500, train loss 1.387282, train error 46.08,  test loss 1.335012, test error 48.50
# Epoch   600, train loss 1.381900, train error 46.50,  test loss 1.333337, test error 48.78
# Epoch   700, train loss 1.379015, train error 46.78,  test loss 1.351933, test error 49.17
# Epoch   800, train loss 1.372511, train error 45.97,  test loss 1.342782, test error 49.45
# Epoch   900, train loss 1.375351, train error 46.42,  test loss 1.351043, test error 49.25
# Training model with  14 hidden variables
# Epoch     0, train loss 2.219283, train error 82.45,  test loss 2.187779, test error 80.62
# Epoch   100, train loss 1.408327, train error 47.10,  test loss 1.308473, test error 48.75
# Epoch   200, train loss 1.329310, train error 44.83,  test loss 1.280650, test error 46.78
# Epoch   300, train loss 1.297380, train error 43.35,  test loss 1.290784, test error 46.72
# Epoch   400, train loss 1.272918, train error 42.92,  test loss 1.308845, test error 46.88
# Epoch   500, train loss 1.259233, train error 42.22,  test loss 1.330826, test error 47.22
# Epoch   600, train loss 1.252922, train error 42.05,  test loss 1.355690, test error 47.60
# Epoch   700, train loss 1.243327, train error 41.80,  test loss 1.358016, test error 47.83
# Epoch   800, train loss 1.241032, train error 41.83,  test loss 1.356561, test error 47.78
# Epoch   900, train loss 1.239833, train error 41.53,  test loss 1.379822, test error 47.72
# Training model with  18 hidden variables
# Epoch     0, train loss 2.255839, train error 83.22,  test loss 2.235271, test error 81.60
# Epoch   100, train loss 1.384016, train error 46.50,  test loss 1.333836, test error 50.35
# Epoch   200, train loss 1.268076, train error 42.70,  test loss 1.350098, test error 50.65
# Epoch   300, train loss 1.229497, train error 40.97,  test loss 1.410936, test error 51.15
# Epoch   400, train loss 1.191488, train error 38.88,  test loss 1.436352, test error 50.50
# Epoch   500, train loss 1.176901, train error 39.15,  test loss 1.482368, test error 50.67
# Epoch   600, train loss 1.167961, train error 38.30,  test loss 1.502606, test error 50.78
# Epoch   700, train loss 1.168875, train error 38.67,  test loss 1.536520, test error 51.78
# Epoch   800, train loss 1.159262, train error 38.92,  test loss 1.565622, test error 51.80
# Epoch   900, train loss 1.155205, train error 38.72,  test loss 1.569139, test error 51.92
# Training model with  22 hidden variables
# Epoch     0, train loss 2.214004, train error 80.88,  test loss 2.210878, test error 81.47
# Epoch   100, train loss 1.267554, train error 43.00,  test loss 1.277399, test error 47.50
# Epoch   200, train loss 1.123434, train error 38.22,  test loss 1.365049, test error 47.60
# Epoch   300, train loss 1.055077, train error 36.50,  test loss 1.452526, test error 49.30
# Epoch   400, train loss 1.027360, train error 35.60,  test loss 1.508734, test error 49.25
# Epoch   500, train loss 0.997747, train error 34.20,  test loss 1.571838, test error 50.78
# Epoch   600, train loss 0.991521, train error 34.57,  test loss 1.622548, test error 51.47
# Epoch   700, train loss 0.976051, train error 33.82,  test loss 1.654987, test error 51.67
# Epoch   800, train loss 0.975171, train error 33.30,  test loss 1.707093, test error 51.95
# Epoch   900, train loss 0.961981, train error 33.25,  test loss 1.739486, test error 51.17
# Training model with  26 hidden variables
# Epoch     0, train loss 2.173895, train error 78.82,  test loss 2.170891, test error 80.70
# Epoch   100, train loss 1.198375, train error 40.30,  test loss 1.336801, test error 49.62
# Epoch   200, train loss 1.033161, train error 34.35,  test loss 1.443753, test error 50.28
# Epoch   300, train loss 0.950763, train error 31.95,  test loss 1.554427, test error 50.22
# Epoch   400, train loss 0.923767, train error 31.03,  test loss 1.681916, test error 52.45
# Epoch   500, train loss 0.884513, train error 29.28,  test loss 1.749336, test error 52.75
# Epoch   600, train loss 0.862382, train error 29.25,  test loss 1.849010, test error 52.92
# Epoch   700, train loss 0.847579, train error 29.10,  test loss 1.959287, test error 53.28
# Epoch   800, train loss 0.835492, train error 27.68,  test loss 2.010712, test error 53.67
# Epoch   900, train loss 0.813821, train error 27.30,  test loss 2.082441, test error 54.05
# Training model with  30 hidden variables
# Epoch     0, train loss 2.176696, train error 80.78,  test loss 2.151777, test error 80.80
# Epoch   100, train loss 1.139942, train error 37.15,  test loss 1.344122, test error 48.40
# Epoch   200, train loss 0.956602, train error 30.95,  test loss 1.536135, test error 51.00
# Epoch   300, train loss 0.850924, train error 27.88,  test loss 1.716409, test error 52.25
# Epoch   400, train loss 0.784869, train error 25.95,  test loss 1.920344, test error 53.17
# Epoch   500, train loss 0.743981, train error 24.45,  test loss 2.123140, test error 55.22
# Epoch   600, train loss 0.737492, train error 25.10,  test loss 2.301861, test error 54.60
# Epoch   700, train loss 0.702975, train error 23.72,  test loss 2.508400, test error 56.97
# Epoch   800, train loss 0.698485, train error 24.30,  test loss 2.567181, test error 55.47
# Epoch   900, train loss 0.700076, train error 24.50,  test loss 2.772848, test error 56.83
# Training model with  35 hidden variables
# Epoch     0, train loss 2.130450, train error 79.30,  test loss 2.111425, test error 78.57
# Epoch   100, train loss 1.003935, train error 33.03,  test loss 1.383271, test error 49.17
# Epoch   200, train loss 0.766843, train error 25.30,  test loss 1.681631, test error 51.72
# Epoch   300, train loss 0.683249, train error 22.90,  test loss 2.023280, test error 52.83
# Epoch   400, train loss 0.616823, train error 20.20,  test loss 2.318832, test error 54.65
# Epoch   500, train loss 0.561085, train error 18.72,  test loss 2.682893, test error 56.12
# Epoch   600, train loss 0.554214, train error 19.35,  test loss 2.967129, test error 56.08
# Epoch   700, train loss 0.476512, train error 15.53,  test loss 3.247049, test error 55.88
# Epoch   800, train loss 0.488148, train error 17.55,  test loss 3.631542, test error 57.88
# Epoch   900, train loss 0.508968, train error 17.72,  test loss 3.972310, test error 57.80
# Training model with  40 hidden variables
# Epoch     0, train loss 2.151576, train error 79.35,  test loss 2.122244, test error 79.07
# Epoch   100, train loss 0.882113, train error 29.32,  test loss 1.435488, test error 49.58
# Epoch   200, train loss 0.624857, train error 20.90,  test loss 1.899649, test error 50.88
# Epoch   300, train loss 0.493137, train error 16.15,  test loss 2.556579, test error 52.35
# Epoch   400, train loss 0.371111, train error 12.43,  test loss 3.277747, test error 53.38
# Epoch   500, train loss 0.326542, train error 11.38,  test loss 4.088864, test error 54.38
# Epoch   600, train loss 0.249065, train error 9.12,  test loss 4.839795, test error 54.30
# Epoch   700, train loss 0.298182, train error 11.15,  test loss 5.624636, test error 54.60
# Epoch   800, train loss 0.228852, train error 8.30,  test loss 6.511837, test error 55.22
# Epoch   900, train loss 0.172979, train error 5.97,  test loss 7.245712, test error 54.90
# Training model with  45 hidden variables
# Epoch     0, train loss 2.090163, train error 76.88,  test loss 2.046210, test error 78.20
# Epoch   100, train loss 0.817827, train error 25.85,  test loss 1.529411, test error 50.60
# Epoch   200, train loss 0.477331, train error 15.60,  test loss 2.333258, test error 53.60
# Epoch   300, train loss 0.259327, train error 7.20,  test loss 3.434044, test error 56.05
# Epoch   400, train loss 0.178127, train error 5.28,  test loss 4.687385, test error 56.97
# Epoch   500, train loss 0.192028, train error 6.75,  test loss 6.008270, test error 57.10
# Epoch   600, train loss 0.019390, train error 0.00,  test loss 7.157779, test error 57.10
# Epoch   700, train loss 0.009397, train error 0.00,  test loss 7.968700, test error 56.97
# Epoch   800, train loss 0.006643, train error 0.00,  test loss 8.511276, test error 57.00
# Epoch   900, train loss 0.005076, train error 0.00,  test loss 8.935863, test error 57.12
# Training model with  50 hidden variables
# Epoch     0, train loss 2.066608, train error 76.03,  test loss 2.038394, test error 75.95
# Epoch   100, train loss 0.680981, train error 21.15,  test loss 1.605034, test error 50.55
# Epoch   200, train loss 0.294498, train error 8.32,  test loss 2.746744, test error 54.03
# Epoch   300, train loss 0.141910, train error 3.70,  test loss 4.332429, test error 54.92
# Epoch   400, train loss 0.026425, train error 0.00,  test loss 5.856565, test error 55.78
# Epoch   500, train loss 0.011929, train error 0.00,  test loss 6.685798, test error 55.15
# Epoch   600, train loss 0.006861, train error 0.00,  test loss 7.297659, test error 55.72
# Epoch   700, train loss 0.004977, train error 0.00,  test loss 7.721765, test error 55.83
# Epoch   800, train loss 0.003878, train error 0.00,  test loss 8.065222, test error 56.00
# Epoch   900, train loss 0.003164, train error 0.00,  test loss 8.339434, test error 55.90
# Training model with  55 hidden variables
# Epoch     0, train loss 2.068022, train error 75.35,  test loss 2.024306, test error 76.50
# Epoch   100, train loss 0.621650, train error 19.50,  test loss 1.642792, test error 50.20
# Epoch   200, train loss 0.218658, train error 5.38,  test loss 2.913621, test error 53.90
# Epoch   300, train loss 0.047921, train error 0.07,  test loss 4.567887, test error 54.75
# Epoch   400, train loss 0.018011, train error 0.00,  test loss 5.719060, test error 55.25
# Epoch   500, train loss 0.010002, train error 0.00,  test loss 6.378980, test error 55.03
# Epoch   600, train loss 0.006597, train error 0.00,  test loss 6.861267, test error 54.97
# Epoch   700, train loss 0.004882, train error 0.00,  test loss 7.233685, test error 55.12
# Epoch   800, train loss 0.003817, train error 0.00,  test loss 7.535744, test error 55.22
# Epoch   900, train loss 0.003111, train error 0.00,  test loss 7.788723, test error 55.28
# Training model with  60 hidden variables
# Epoch     0, train loss 2.049267, train error 76.78,  test loss 1.986737, test error 75.97
# Epoch   100, train loss 0.528627, train error 15.22,  test loss 1.688568, test error 49.67
# Epoch   200, train loss 0.119202, train error 1.07,  test loss 3.252739, test error 52.95
# Epoch   300, train loss 0.020723, train error 0.00,  test loss 4.571072, test error 53.60
# Epoch   400, train loss 0.010017, train error 0.00,  test loss 5.242324, test error 53.62
# Epoch   500, train loss 0.006321, train error 0.00,  test loss 5.692882, test error 53.95
# Epoch   600, train loss 0.004497, train error 0.00,  test loss 6.027604, test error 53.92
# Epoch   700, train loss 0.003432, train error 0.00,  test loss 6.285356, test error 54.12
# Epoch   800, train loss 0.002761, train error 0.00,  test loss 6.507919, test error 54.05
# Epoch   900, train loss 0.002297, train error 0.00,  test loss 6.693295, test error 54.17
# Training model with  70 hidden variables
# Epoch     0, train loss 2.030474, train error 76.05,  test loss 1.964048, test error 75.18
# Epoch   100, train loss 0.347166, train error 9.50,  test loss 1.916845, test error 50.58
# Epoch   200, train loss 0.030184, train error 0.00,  test loss 3.557620, test error 52.17
# Epoch   300, train loss 0.010717, train error 0.00,  test loss 4.324504, test error 53.17
# Epoch   400, train loss 0.006019, train error 0.00,  test loss 4.758568, test error 53.40
# Epoch   500, train loss 0.004091, train error 0.00,  test loss 5.061029, test error 53.67
# Epoch   600, train loss 0.003039, train error 0.00,  test loss 5.287760, test error 53.90
# Epoch   700, train loss 0.002389, train error 0.00,  test loss 5.471954, test error 53.75
# Epoch   800, train loss 0.001959, train error 0.00,  test loss 5.627733, test error 53.83
# Epoch   900, train loss 0.001647, train error 0.00,  test loss 5.761448, test error 53.88
# Training model with  80 hidden variables
# Epoch     0, train loss 2.026877, train error 74.68,  test loss 1.967018, test error 74.30
# Epoch   100, train loss 0.217702, train error 3.38,  test loss 2.051094, test error 50.12
# Epoch   200, train loss 0.019500, train error 0.00,  test loss 3.384976, test error 51.70
# Epoch   300, train loss 0.007922, train error 0.00,  test loss 3.932676, test error 51.67
# Epoch   400, train loss 0.004674, train error 0.00,  test loss 4.265503, test error 51.83
# Epoch   500, train loss 0.003231, train error 0.00,  test loss 4.495541, test error 52.05
# Epoch   600, train loss 0.002431, train error 0.00,  test loss 4.676863, test error 52.03
# Epoch   700, train loss 0.001931, train error 0.00,  test loss 4.822010, test error 51.95
# Epoch   800, train loss 0.001591, train error 0.00,  test loss 4.946555, test error 52.08
# Epoch   900, train loss 0.001346, train error 0.00,  test loss 5.052613, test error 52.12
# Training model with  90 hidden variables
# Epoch     0, train loss 1.991885, train error 73.78,  test loss 1.927874, test error 74.72
# Epoch   100, train loss 0.150261, train error 1.68,  test loss 2.311914, test error 53.83
# Epoch   200, train loss 0.014993, train error 0.00,  test loss 3.396243, test error 53.40
# Epoch   300, train loss 0.006624, train error 0.00,  test loss 3.842230, test error 53.53
# Epoch   400, train loss 0.004049, train error 0.00,  test loss 4.118933, test error 53.60
# Epoch   500, train loss 0.002842, train error 0.00,  test loss 4.316785, test error 53.50
# Epoch   600, train loss 0.002161, train error 0.00,  test loss 4.471598, test error 53.45
# Epoch   700, train loss 0.001728, train error 0.00,  test loss 4.598009, test error 53.42
# Epoch   800, train loss 0.001431, train error 0.00,  test loss 4.705886, test error 53.53
# Epoch   900, train loss 0.001214, train error 0.00,  test loss 4.799720, test error 53.53
# Training model with 100 hidden variables
# Epoch     0, train loss 1.989909, train error 74.25,  test loss 1.919884, test error 73.45
# Epoch   100, train loss 0.095147, train error 0.22,  test loss 2.323047, test error 51.55
# Epoch   200, train loss 0.012123, train error 0.00,  test loss 3.209426, test error 52.12
# Epoch   300, train loss 0.005637, train error 0.00,  test loss 3.585594, test error 52.33
# Epoch   400, train loss 0.003535, train error 0.00,  test loss 3.822313, test error 52.30
# Epoch   500, train loss 0.002507, train error 0.00,  test loss 3.996403, test error 52.45
# Epoch   600, train loss 0.001921, train error 0.00,  test loss 4.131879, test error 52.40
# Epoch   700, train loss 0.001543, train error 0.00,  test loss 4.244812, test error 52.40
# Epoch   800, train loss 0.001281, train error 0.00,  test loss 4.338108, test error 52.50
# Epoch   900, train loss 0.001091, train error 0.00,  test loss 4.419858, test error 52.47
# Training model with 120 hidden variables
# Epoch     0, train loss 1.975221, train error 74.80,  test loss 1.891950, test error 73.85
# Epoch   100, train loss 0.049706, train error 0.00,  test loss 2.211945, test error 51.30
# Epoch   200, train loss 0.009390, train error 0.00,  test loss 2.814710, test error 50.92
# Epoch   300, train loss 0.004681, train error 0.00,  test loss 3.089606, test error 51.10
# Epoch   400, train loss 0.002976, train error 0.00,  test loss 3.265332, test error 51.22
# Epoch   500, train loss 0.002151, train error 0.00,  test loss 3.394342, test error 51.30
# Epoch   600, train loss 0.001660, train error 0.00,  test loss 3.499644, test error 51.38
# Epoch   700, train loss 0.001342, train error 0.00,  test loss 3.586300, test error 51.30
# Epoch   800, train loss 0.001120, train error 0.00,  test loss 3.659404, test error 51.30
# Epoch   900, train loss 0.000957, train error 0.00,  test loss 3.724153, test error 51.30
# Training model with 140 hidden variables
# Epoch     0, train loss 1.964264, train error 73.70,  test loss 1.925543, test error 75.05
# Epoch   100, train loss 0.036455, train error 0.00,  test loss 2.188625, test error 49.85
# Epoch   200, train loss 0.008055, train error 0.00,  test loss 2.689641, test error 50.22
# Epoch   300, train loss 0.004129, train error 0.00,  test loss 2.925987, test error 50.50
# Epoch   400, train loss 0.002681, train error 0.00,  test loss 3.080125, test error 50.47
# Epoch   500, train loss 0.001948, train error 0.00,  test loss 3.192957, test error 50.47
# Epoch   600, train loss 0.001514, train error 0.00,  test loss 3.284309, test error 50.42
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.360029, test error 50.40
# Epoch   800, train loss 0.001029, train error 0.00,  test loss 3.424943, test error 50.35
# Epoch   900, train loss 0.000881, train error 0.00,  test loss 3.481506, test error 50.33
# Training model with 160 hidden variables
# Epoch     0, train loss 1.920715, train error 70.68,  test loss 1.851840, test error 71.55
# Epoch   100, train loss 0.029020, train error 0.00,  test loss 2.157971, test error 50.17
# Epoch   200, train loss 0.007218, train error 0.00,  test loss 2.585626, test error 50.20
# Epoch   300, train loss 0.003799, train error 0.00,  test loss 2.794394, test error 50.17
# Epoch   400, train loss 0.002498, train error 0.00,  test loss 2.932036, test error 50.03
# Epoch   500, train loss 0.001828, train error 0.00,  test loss 3.033377, test error 49.95
# Epoch   600, train loss 0.001427, train error 0.00,  test loss 3.114769, test error 49.92
# Epoch   700, train loss 0.001162, train error 0.00,  test loss 3.182760, test error 49.97
# Epoch   800, train loss 0.000975, train error 0.00,  test loss 3.240819, test error 49.95
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.291366, test error 49.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.937199, train error 72.05,  test loss 1.876993, test error 74.12
# Epoch   100, train loss 0.025984, train error 0.00,  test loss 2.046288, test error 48.72
# Epoch   200, train loss 0.006794, train error 0.00,  test loss 2.411330, test error 48.83
# Epoch   300, train loss 0.003624, train error 0.00,  test loss 2.588524, test error 48.88
# Epoch   400, train loss 0.002399, train error 0.00,  test loss 2.709025, test error 48.90
# Epoch   500, train loss 0.001760, train error 0.00,  test loss 2.797201, test error 48.88
# Epoch   600, train loss 0.001378, train error 0.00,  test loss 2.868681, test error 48.72
# Epoch   700, train loss 0.001124, train error 0.00,  test loss 2.928674, test error 48.78
# Epoch   800, train loss 0.000945, train error 0.00,  test loss 2.979366, test error 48.72
# Epoch   900, train loss 0.000812, train error 0.00,  test loss 3.024100, test error 48.83
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926769, train error 71.50,  test loss 1.862727, test error 72.30
# Epoch   100, train loss 0.021639, train error 0.00,  test loss 1.995057, test error 47.65
# Epoch   200, train loss 0.006179, train error 0.00,  test loss 2.318794, test error 48.03
# Epoch   300, train loss 0.003340, train error 0.00,  test loss 2.481052, test error 47.70
# Epoch   400, train loss 0.002222, train error 0.00,  test loss 2.591488, test error 47.53
# Epoch   500, train loss 0.001641, train error 0.00,  test loss 2.673308, test error 47.42
# Epoch   600, train loss 0.001289, train error 0.00,  test loss 2.740546, test error 47.45
# Epoch   700, train loss 0.001054, train error 0.00,  test loss 2.796501, test error 47.47
# Epoch   800, train loss 0.000888, train error 0.00,  test loss 2.844146, test error 47.50
# Epoch   900, train loss 0.000764, train error 0.00,  test loss 2.886600, test error 47.72
# Training model with 250 hidden variables
# Epoch     0, train loss 1.920583, train error 70.70,  test loss 1.837328, test error 71.55
# Epoch   100, train loss 0.017020, train error 0.00,  test loss 1.932863, test error 47.65
# Epoch   200, train loss 0.005338, train error 0.00,  test loss 2.183691, test error 47.35
# Epoch   300, train loss 0.002971, train error 0.00,  test loss 2.319598, test error 47.38
# Epoch   400, train loss 0.002005, train error 0.00,  test loss 2.411811, test error 47.33
# Epoch   500, train loss 0.001492, train error 0.00,  test loss 2.482496, test error 47.35
# Epoch   600, train loss 0.001177, train error 0.00,  test loss 2.539657, test error 47.20
# Epoch   700, train loss 0.000967, train error 0.00,  test loss 2.587274, test error 47.20
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.628532, test error 47.28
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.664943, test error 47.30
# Training model with 300 hidden variables
# Epoch     0, train loss 1.883994, train error 68.47,  test loss 1.835527, test error 71.18
# Epoch   100, train loss 0.014763, train error 0.00,  test loss 1.796046, test error 45.85
# Epoch   200, train loss 0.004875, train error 0.00,  test loss 2.007972, test error 45.45
# Epoch   300, train loss 0.002755, train error 0.00,  test loss 2.124280, test error 45.28
# Epoch   400, train loss 0.001876, train error 0.00,  test loss 2.202682, test error 45.47
# Epoch   500, train loss 0.001402, train error 0.00,  test loss 2.263789, test error 45.35
# Epoch   600, train loss 0.001111, train error 0.00,  test loss 2.313178, test error 45.33
# Epoch   700, train loss 0.000914, train error 0.00,  test loss 2.354673, test error 45.25
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.390223, test error 45.20
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.421331, test error 45.28
# Training model with 400 hidden variables
# Epoch     0, train loss 1.847458, train error 67.20,  test loss 1.812474, test error 70.75
# Epoch   100, train loss 0.011496, train error 0.00,  test loss 1.793368, test error 46.33
# Epoch   200, train loss 0.004126, train error 0.00,  test loss 1.970356, test error 46.33
# Epoch   300, train loss 0.002391, train error 0.00,  test loss 2.068883, test error 46.38
# Epoch   400, train loss 0.001648, train error 0.00,  test loss 2.136947, test error 46.33
# Epoch   500, train loss 0.001242, train error 0.00,  test loss 2.189361, test error 46.28
# Epoch   600, train loss 0.000989, train error 0.00,  test loss 2.231898, test error 46.28
# Epoch   700, train loss 0.000817, train error 0.00,  test loss 2.267317, test error 46.30
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.298531, test error 46.33
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.325499, test error 46.42

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
